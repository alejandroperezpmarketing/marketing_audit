# %%
#funciones

# %%
import twitter
import json
from collections import Counter
import os 
import nltk
nltk.download('vader_lexicon')
import matplotlib.pyplot as plt
from prettytable import PrettyTable
from collections import Counter
import numpy as np
from nltk.sentiment.vader import SentimentIntensityAnalyzer



data_folder = os.path.join(os.path.expanduser("~"), "Data", "twitter")
output_filename = os.path.join(data_folder, "python_tweets.json")
# Go to https://developer.twitter.com/en/apps to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://developer.twitter.com/en/docs/basics/authentication/overview/oauth
# for more information on Twitter's OAuth implementation.

CONSUMER_KEY = 'soYOytOxNqM3iOTqAeIbxnlDX'
CONSUMER_SECRET = 'AMMUddKaTwR6Y8VehQmVnH1jKPHBSMEvG31W7OjWYrl3tiqXkR'
OAUTH_TOKEN = '1429859845545631749-kZgY0wLEpKLsCqrRe6BTwK0IfcIxc8'
OAUTH_TOKEN_SECRET = 'ZXqMhYZ3F9d97RyAZMuI2e2myCb3cCdXf462ToXmDG9sB'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\Alejandro
# [nltk_data]     Perez\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# ...

# %%
auth = twitter.oauth.OAuth(OAUTH_TOKEN,OAUTH_TOKEN_SECRET, CONSUMER_KEY, CONSUMER_SECRET)

# %%
twitter_api = twitter.Twitter(auth=auth)

# %%
print(twitter_api)

# %%
#import twitter
#consumer_key = "<Your Consumer Key Here>"
#consumer_secret = "<Your Consumer Secret Here>"
#access_token = "<Your Access Token Here>"
#access_token_secret = "<Your Access Token Secret Here>"
#authorization = twitter.OAuth(access_token, 
#access_token_secret, consumer_key, consumer_secret)
#t = twitter.Twitter(auth=authorization, retry=True)

# %%
tweets = []
original_users = [] 
tweets_turismo_digital = []
tweets_naturaleza = []
tweets_marketing_digital = []
tweets_marketing = []
tweets_turismo = []
user_ids = {}

# %%
search_results_marketing_digital = twitter_api.search.tweets(q="marketing digital", count=1000)['statuses']
for tweet in search_results_marketing_digital:
    if 'text' in tweet:
        if tweet['lang'] == 'es':
            original_users.append(tweet['user']['screen_name']) 
            user_ids[tweet['user']['screen_name']] = tweet['user']['id']
            tweets_marketing_digital.append(tweet['text'])
            
            
search_marketing = twitter_api.search.tweets(q="marketing", count=1000)['statuses']
for tweet in search_marketing:
    if 'text' in tweet:
        if tweet['lang'] == 'es':
            original_users.append(tweet['user']['screen_name']) 
            user_ids[tweet['user']['screen_name']] = tweet['user']['id']
            tweets_marketing.append(tweet['text']) 
            
            
search_results_turismo_digital = twitter_api.search.tweets(q="turismo digital", count=1000)['statuses']
for tweet in search_results_marketing_digital:
    if 'text' in tweet:
        if tweet['lang'] == 'es':
            original_users.append(tweet['user']['screen_name']) 
            user_ids[tweet['user']['screen_name']] = tweet['user']['id']
            tweets_turismo_digital.append(tweet['text'])
            
            
search_results_naturaleza = twitter_api.search.tweets(q="naturaleza", count=1000)['statuses']
for tweet in search_results_naturaleza:
    if 'text' in tweet:
        if tweet['lang'] == 'es':
            original_users.append(tweet['user']['screen_name']) 
            user_ids[tweet['user']['screen_name']] = tweet['user']['id']
            tweets_naturaleza.append(tweet['text'])  
            
            
search_results_turismo = twitter_api.search.tweets(q="turismo", count=1000)['statuses']
for tweet in search_results_turismo:
    if 'text' in tweet:
        if tweet['lang'] == 'es':
            original_users.append(tweet['user']['screen_name']) 
            user_ids[tweet['user']['screen_name']] = tweet['user']['id']
            tweets_turismo.append(tweet['text'])

# %%
tweets_marketing_digital
# Out:
# ['El jaque mate de España a las triquiñuelas (desleales) de los influencers. https://t.co/owgQCbhLET',
#  'RT @Lonettap: Te invito a seguir mi cuenta como Agencia de Marketing Digital @mymate_digital. Se vienen charlas #gratis sobre @ML_Argentina…',
#  '7 métricas principales en Marketing Digital https://t.co/I5CV1LdNnP https://t.co/C7EAQAOblc',
#  'Te invito a seguir mi cuenta como Agencia de Marketing Digital @mymate_digital. Se vienen charlas #gratis sobre… https://t.co/BW1fD4yczz',
#  'Este es un ejemplo genial de adaptación de contenido al verano🏖\n\nSpotify trae las verbenas de pueblo a una playlist… https://t.co/lyjLHYUiJj']

# %%
tweets_turismo_digital
# Out:
# ['Conoce ¿qué beneficios tiene una buena comunicación en marketing digital? a través de un conversatorio de expertos… https://t.co/drUnkaArSs',
#  'NUEVOS CLIENTES PARA TU NEGOCIO 🙌 📊💪\n~Aumentamos tus #Ventas📣~\n&gt;Marketing Digital\n&gt;Aumentamos tus ventas\n&gt;Publicida… https://t.co/W7HYzCyeFh',
#  'Qué es la presencia online y cómo incrementarla\n ► https://t.co/8Xi8s3Tf6y',
#  'No te pierdas a @LauRuval y @Roskca de @BRAINmx en el #TalkIn21 quienes nos compartirán el tema: Marketing digital… https://t.co/MxHeCpGOUl',
#  '¿Qué tan conocidas son las #criptodivisas y cuanta gente las posee?\n\n👉 https://t.co/bH7nS9zFfb\n\n#BTC #ETH #Bitcoin… https://t.co/fxNSeznxD9',
#  'El jaque mate de España a las triquiñuelas (desleales) de los influencers. https://t.co/owgQCbhLET',
#  'RT @Lonettap: Te invito a seguir mi cuenta como Agencia de Marketing Digital @mymate_digital. Se vienen charlas #gratis sobre @ML_Argentina…']

# %%
tweets_naturaleza
# Out:
# ['RT @utso_04trujillo: #24Ago 🗓️ Día Internacional de los Parques Naturales🌻,  para recordar a la sociedad la importancia que tiene la conser…',
#  'RT @fridelis: #24Ago ¡SOLIDARIOS! La gente de #SantaCruzdeMora y #Tovar en #Mérida está sufriendo los embates de la naturaleza NO es moment…',
#  'Respuestas cuñadas a este tweet que refleja la realidad: que las mujeres seguimos teniendo un techo de cristal a la… https://t.co/uN6j5aOAyU',
#  'RT @xataka: El "asfalto frío" no es ninguna broma: puede bajar 2º la temperatura de las ciudades y reducir hasta un 6% sus emisiones según…',
#  'RT @DiazCanelB: En el Día Mundial de los Parques Naturales, agradezco a quienes viven y trabajan en los nuestros, su contribución a la salu…',
#  'RT @reddearte: #Agenda #24Agosto "Día Internacional de los Parques Naturales" se celebra para educar a la población mundial sobre la import…',
# ...

# %%
tweets_marketing
# Out:
# ['¿Cómo? Por medio de un análisis que permita evaluar el retorno de la inversión.\n\nAhora que lo sabes es hora de revi… https://t.co/N1Z79ycux0',
#  '✅Descuidar la medición de resultados. Gracias al marketing digital ya es posible saber, si un mensaje llegó, se ley… https://t.co/EznWAAC2hb',
#  '✅Pensar que invertir es una pérdida de dinero. Esto pasa cuando no hay una estrategia de marketing respaldando la i… https://t.co/2yYWy2Jq16',
#  'Algún día te has preguntado ¿qué sucede cuando una estrategia de marketing digital no cumple con los requerimientos… https://t.co/CRwQngKB2E',
#  'RT @carlosfabaro: @rayude68 @gigighi @Marinasolcano @Florenc72980529 @virpascual @LinaresVirginia @raulgallard @fsusbielles @juanodell @Can…',
#  'Antes era periodista, hoy me apasiono hablando de Marketing Digital en la radio y estoy cebado por el trailer de NW… https://t.co/ZnTqz4VDhG',
# ...

# %%
tweets_turismo
# Out:
# ['RT @EFEnoticias: El turismo nacional ya supera el dato pre covid en la mayoría de las comunidades.\n\nhttps://t.co/19NizinX2i',
#  'RT @imsanantoniocl: San Antonio avanza a fase 4 de Apertura Inicial en el Plan Paso a Paso https://t.co/7uuYDAIXhq',
#  'Superordenadores, robots sexuales, turismo espacial: muchos de los inventos que definirán el futuro están hoy con\xa0n… https://t.co/osyRWsNh2I',
#  'RT @mgore85: Un pais con el doble o triple de paro que los de su entorno deberia estar pensando qué sectores revitalizar. En vez de eso nos…',
#  '🆕 ENTRADAS A LA VENTA 🆕\n\n🎟 Disfruta de la novillada de Benassal por 10€\n\nEstos días no pierdas la oportunidad de co… https://t.co/QfodPsRiNW',
#  'RT @sai_turismo: Les tenemos una sorpresa !\n📸 En el marco del Día Mundial de la fotografía, les presentamos nuestro Concurso "Tu puesta de…',
#  'RT @salvartejita: Óscar Izquierdo mintiendo en linkedin diciendo que Tenerife quiere el Puerto de Fonsalía. Es algo muy normal para los ama…',
# ...

# %%
#for twitter streaming API
#twitter_stream = twitter.TwitterStream(auth=auth)
#iterator = twitter_stream.statuses.sample()


analyzer = SentimentIntensityAnalyzer()

# %%
analyzer.polarity_scores('Hello')
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
scores = np.zeros(len(tweets_marketing))

for i, t in enumerate(tweets_marketing):
    # Extract the text portion of the tweet
    text = t['text']
    
    # Measure the polarity of the tweet
    polarity = analyzer.polarity_scores(text)
    
    # Store the normalized, weighted composite score
    scores[i] = polarity['compound']

# %%
review = "I like this phone. screen quality and camera clarity is really good"

#import libraries
from textblob import TextBlob
#TextBlob has a pre trained sentiment prediction model
blob = TextBlob(review)
blob.sentiment
# Out:
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)

# %%
print('{0:6.3f} : "{1}"'.format(scores[most_positive], tweets_marketing[most_positive]['text']))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-157-d04042f9bdb2> in <module>
# ----> 1 print('{0:6.3f} : "{1}"'.format(scores[most_positive], tweets_marketing[most_positive]['text']))
#
# IndexError: index 2 is out of bounds for axis 0 with size 0

# %%
print('{0:6.3f} : "{1}"'.format(scores[most_negative], tweets[most_negative]['text']))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-151-998db731b142> in <module>
# ----> 1 print('{0:6.3f} : "{1}"'.format(scores[most_negative], tweets[most_negative]['text']))
#
# IndexError: index 4 is out of bounds for axis 0 with size 0

# %%
  # Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Import libraries
from nltk.corpus import stopwords
from textblob import TextBlob
from textblob import Word

# %%
count = 20
query = "vaccine"
tweets = twitter_api.search.tweets(q=query, count=count, 
   lang='en',tweet_mode="extended")

# %%
tweetsWithSent = []
for t in tweets['statuses']:
   text = (t['full_text'])
   ps = analyzer.polarity_scores(text)
   tweetsWithSent.append({'text':text, 'compound':ps['compound']})

# %%
import pandas as pd
tweetdf = pd.DataFrame(tweetsWithSent)
tweetdf.plot.bar(figsize=(15,5),width=1)
# Out:
# <AxesSubplot:>

# %%
ps = analyzer.polarity_scores("Have a safe 2021")
print(ps)
{'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}
# Out:
# {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}
# {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}

# %%
tweetdf
# Out:
#                                                  text  compound
# 0   @BrianVS60 @ByRyanWood Well, go take a look at...    0.5267
# 1   RT @Trumpeteer14: 🇺🇸 What do you think of the ...    0.4767
# 2   RT @BernieSpofforth: ISRAEL PM - the vaccines ...    0.0000
# 3         @b00tlegspr1te Buy and then get the vaccine    0.0000
# 4   RT @djrothkopf: Right now, the administration ...    0.0000
# 5   RT @DesignerKru: americans: i'm not getting no...    0.5842
# 6   Got my second covid-19 vaccine yesterday, litt...    0.4891
# 7   RT @SHEsus__Christ: Reminder: You have to wear...    0.0000
# 8   RT @RealCandaceO: To be clear— employees of th...    0.4215
# 9   RT @anet2111: More heat advisories this year t...    0.0000
# 10  Why does Ben play pretend as if there are no c...    0.5905
# 11  RT @ChrisExcel102: They will not force us to t...    0.2732
# 12  And the ignorant anti-vaxers are making it 10 ...   -0.8479
# 13  RT @benshapiro: Zero covid will never be reali...    0.0000
# ...

# %%
#Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re
import os
import sys
import ast
#!pip install vaderSentiment

plt.style.use('fivethirtyeight')

# Function for getting the sentiment
cp = sns.color_palette()

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

# Generating sentiment for all the sentence present in the dataset

emptyline=[]

for row in tweetdf['text']:
    vs = analyzer.polarity_scores(row)
    emptyline.append(vs)
    
# Creating new dataframe with sentiments 
df_sentiments=pd.DataFrame(emptyline)
df_sentiments
# Out:
#       neg    neu    pos  compound
# 0   0.000  0.820  0.180    0.5267
# 1   0.000  0.819  0.181    0.4767
# 2   0.000  1.000  0.000    0.0000
# 3   0.000  1.000  0.000    0.0000
# 4   0.000  1.000  0.000    0.0000
# 5   0.000  0.770  0.230    0.5842
# 6   0.092  0.691  0.217    0.4891
# 7   0.000  1.000  0.000    0.0000
# 8   0.000  0.896  0.104    0.4215
# 9   0.000  1.000  0.000    0.0000
# 10  0.088  0.731  0.181    0.5905
# 11  0.000  0.909  0.091    0.2732
# 12  0.236  0.764  0.000   -0.8479
# 13  0.000  1.000  0.000    0.0000
# 14  0.000  1.000  0.000    0.0000
# 15  0.000  0.793  0.207    0.5661
# 16  0.333  0.667  0.000   -0.7579
# 17  0.000  0.841  0.159    0.6740
# 18  0.116  0.745  0.139    0.1200
# 19  0.125  0.875  0.000   -0.6597

# %%
# Convert scores into positive and negetive sentiments using some threshold
df_sentiments['Sentiment'] = np.where(df_sentiments['compound'] >= 0 , 'Positive', 'Negative')
df_c.head(5)

#output sample


result=df_c['Sentiment'].value_counts()
result.plot(kind='bar', rot=0,color='black');
df_sentiments
# Out:
#       neg    neu    pos  compound Sentiment
# 0   0.000  0.820  0.180    0.5267  Positive
# 1   0.000  0.819  0.181    0.4767  Positive
# 2   0.000  1.000  0.000    0.0000  Positive
# 3   0.000  1.000  0.000    0.0000  Positive
# 4   0.000  1.000  0.000    0.0000  Positive
# 5   0.000  0.770  0.230    0.5842  Positive
# 6   0.092  0.691  0.217    0.4891  Positive
# 7   0.000  1.000  0.000    0.0000  Positive
# 8   0.000  0.896  0.104    0.4215  Positive
# 9   0.000  1.000  0.000    0.0000  Positive
# 10  0.088  0.731  0.181    0.5905  Positive
# 11  0.000  0.909  0.091    0.2732  Positive
# 12  0.236  0.764  0.000   -0.8479  Negative
# 13  0.000  1.000  0.000    0.0000  Positive
# 14  0.000  1.000  0.000    0.0000  Positive
# 15  0.000  0.793  0.207    0.5661  Positive
# 16  0.333  0.667  0.000   -0.7579  Negative
# 17  0.000  0.841  0.159    0.6740  Positive
# 18  0.116  0.745  0.139    0.1200  Positive
# 19  0.125  0.875  0.000   -0.6597  Negative

# %%
#Sample code snippet
result=df_c.groupby('compound')['Sentiment'].value_counts().unstack()
result[['Negative','Positive']].plot(kind='bar', 
stacked=True, color='rb')
# Out:
# <AxesSubplot:xlabel='compound'>
